# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/spaceship-titanic/sample_submission.csv
# /kaggle/input/spaceship-titanic/train.csv
# /kaggle/input/spaceship-titanic/test.csv

# %% [markdown]
# # Getting familiar with the data

# %%
X = pd.read_csv('/kaggle/input/spaceship-titanic/train.csv')
y = pd.read_csv('/kaggle/input/spaceship-titanic/test.csv')

# %%
X.columns.values, X.shape, X.isnull().sum()
# Out:
# (array(['PassengerId', 'HomePlanet', 'CryoSleep', 'Cabin', 'Destination',
#         'Age', 'VIP', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa',
#         'VRDeck', 'Name', 'Transported'], dtype=object),
#  (8693, 14),
#  PassengerId       0
#  HomePlanet      201
#  CryoSleep       217
#  Cabin           199
#  Destination     182
#  Age             179
#  VIP             203
#  RoomService     181
#  FoodCourt       183
#  ShoppingMall    208
#  Spa             183
#  VRDeck          188
#  Name            200
#  Transported       0
#  dtype: int64)

# %%
y.columns.values, y.shape
# Out:
# (array(['PassengerId', 'HomePlanet', 'CryoSleep', 'Cabin', 'Destination',
#         'Age', 'VIP', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa',
#         'VRDeck', 'Name'], dtype=object),
#  (4277, 13))

# %%
N = 2
X.head

X[['HomePlanet','Destination', 'Transported']].groupby(['Transported', 'HomePlanet', 'Destination']).size()
# Out:
# Transported  HomePlanet  Destination
# False        Earth       55 Cancri e       342
#                          PSO J318.5-22     357
#                          TRAPPIST-1e      1894
#              Europa      55 Cancri e       275
#                          PSO J318.5-22       5
#                          TRAPPIST-1e       434
#              Mars        55 Cancri e        75
#                          PSO J318.5-22      27
#                          TRAPPIST-1e       720
# True         Earth       55 Cancri e       348
#                          PSO J318.5-22     355
#                          TRAPPIST-1e      1207
#              Europa      55 Cancri e       611
#                          PSO J318.5-22      14
#                          TRAPPIST-1e       755
#              Mars        55 Cancri e       118
#                          PSO J318.5-22      22
#                          TRAPPIST-1e       755
# dtype: int64

# %%
columns=['HomePlanet', 'Destination', 'Age', 'VIP']
X_train = X[columns]
y_train = X['Transported']

X_test = y[columns]
y_test = y['Transported']
